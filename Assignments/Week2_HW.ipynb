# %% [markdown]
# <a href="https://colab.research.google.com/github/mezniyoussef206-hub/Data201-labs/blob/main/Assignments/Week2_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HomeWork 2

# %%
import numpy as np
import pandas as pd

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2313/1096904589.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 college = pd.read_csv("/content/drive/MyDrive/college.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
college = pd.read_csv("/content/drive/My Drive/Data 201/Datasets/College.csv")

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college2 = pd.read_csv('/content/drive/My Drive/Data 201/Datasets/College.csv', index_col=0)

college3 = college.rename({'Unnamed: 0': 'College'},
                          axis=1)

college3 = college3.set_index('College')

# %%
college = college3

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          [0, 50, 100],
                          labels=['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college['Elite'].value_counts(dropna=False)
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college['Top10perc'].describe()
# Out:
# count    777.000000
# mean      27.558559
# std       17.640364
# min        1.000000
# 25%       15.000000
# 50%       23.000000
# 75%       35.000000
# max       96.000000
# Name: Top10perc, dtype: float64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, figsize=(10, 8))

college['Apps'].plot.hist(bins=10, ax=ax[0, 0])
ax[0, 0].set_title('Applications')

college['Enroll'].plot.hist(bins=15, ax=ax[0, 1])
ax[0, 1].set_title('Enrollment')

college['Outstate'].plot.hist(bins=20, ax=ax[1, 0])
ax[1, 0].set_title('Out-of-State Tuition')

college['Grad.Rate'].plot.hist(bins=25, ax=ax[1, 1])
ax[1, 1].set_title('Graduation Rate')

plt.tight_layout()
plt.show()

# %% [markdown]
# from the graphs, I noticed that applications and enrollment are strngly right-skewed, meaning most colleges receive a relatively low number of applications and enrol a relatively low numbers of students, while a few colleges have much higher application and enrollment numbers.
#
# Private colleges generally have higher out-of-state tuition than public colleges.
#
# Elite colleges also appear to have higher out-of-state tuition than non-elite colleges.
#
# the scatterplot matrix shows a strong positive relationship between applications and enrollment,while Top10per seems to have a weaker positive relationship with them. Gradution rates are mostly around the middle-to-high range, with a possible outlier aboves 100%.

# %% [markdown]
# Question 9

# %%
import pandas as pd
auto = pd.read_csv("/content/drive/My Drive/Data 201/Datasets/Auto.csv")

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
#  quantitative:mpg,displacment,horsepower,weight,acceleration,year
#  qualitative:cylinders,origin,name

# %%
auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
auto['mpg'].min()
auto['mpg'].max()
print(auto['mpg'].min())
print(auto['mpg'].max())
# Out:
# 9.0
# 46.6

# %%
auto['displacement'].min()
auto['displacement'].max()
print(auto['displacement'].min())
print(auto['displacement'].max())
# Out:
# 68.0
# 455.0

# %%
auto['horsepower'].min()
auto['horsepower'].max()
print(auto['horsepower'].min())
print(auto['horsepower'].max())
# Out:
# 100
# ?

# %%
auto['weight'].min()
auto['weight'].max()
print(auto['weight'].min())
print(auto['weight'].max())
# Out:
# 1613
# 5140

# %%
auto['acceleration'].min()
auto['acceleration'].max()
print(auto['acceleration'].min())
print(auto['acceleration'].max())
# Out:
# 8.0
# 24.8

# %%
auto['year'].min()
auto['year'].max()
print(auto['year'].min())
print(auto['year'].max())
# Out:
# 70
# 82

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
Auto_subset = auto.drop(auto.index[9:85])

# %%
Auto_subset.shape
# Out:
# (321, 9)

# %%
Auto_subset.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.438629    5.370717    187.049844  2933.962617     15.723053
# std      7.908184    1.653486     99.635385   810.642938      2.680514
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  321.000000  321.000000
# mean    77.152648    1.598131
# std      3.111230    0.816163
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(auto["weight"], auto["mpg"])

plt.xlabel("Weight")
plt.ylabel("MPG")
plt.title("Weight vs. MPG")

plt.show()

# %% [markdown]
# The scatterplot shows a clear negative relationship between car weight and MPG. Lighter cars tend to have higher MPG, while heavier cars tend to have lower MPG. The pattern is fairly strong, although there are a few cars that do not follow the trend exactly.

# %% [markdown]
# Question 10

# %%
Boston = pd.read_csv("/content/drive/My Drive/Data 201/Datasets/Boston.csv")

# %%
Boston.shape
# Out:
# (506, 14)

# %%
pd.plotting.scatter_matrix(
    Boston[['crim', 'rm', 'lstat', 'tax']],
    figsize=(10, 10)
)

plt.show()

# %% [markdown]
# The plots show a clear negative relationship between rm and lstat, meaning areas with more rooms generally have lower lstat values. Crime rate (crim) tends to be higher when lstat and tax are higher, although the relationship is not very strong for every observation. The crime variable is also highly right-skewed, with a few areas having extremely high crime rates. Overall, some predictors show noticeable relationships, while others are more scattered.

# %% [markdown]
# Crime rate tends to be higher in areas with higher rad, tax, lstat, nox, and indus values. In contrast, crime rate tends to decrease as dis and rm increase. Among these variables, rad and tax show some of the strongest positive relationships with crime rate.

# %%
Boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# Some suburbs appear to have particularly high crime rates. The maximum crime rate is about 88.98, while the 75th percentile is only about 3.68, so a few areas have extremely high crime compared with most of the dataset. Tax rates range from 187 to 711, showing a large amount of variation. Pupil-teacher ratios range from 12.6 to 22.0, so their range is much smaller.
#
# For the predictor ranges:
# - crim: about 88.97
# - zn: 100
# - indus: 27.28
# - chas: 1
# - nox: about 0.49
# - rm: about 5.22
# - age: 97.1
# - dis: about 11.00
# - rad: 23
# - tax: 524
# - ptratio: 9.4
# - lstat: 36.24

# %%
Boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
Boston['ptratio'].median()
# Out:
# 19.05

# %%
Boston['medv'].min()
# Out:
# 5.0

# %%
Boston[Boston['medv'] == 5.0]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio  lstat  medv
# 398  666     20.2  30.59   5.0
# 405  666     20.2  22.98   5.0

# %%
Boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# The two observations with the lowest median home value have medv = 5.0. Both have very high crime rates, an age value of 100, the maximum rad value of 24, and high tax rates of 666. They also have relatively high lstat values and relatively low numbers of rooms. Overall, these observations have several extreme or unfavorable characteristics compared with the rest of the dataset, which may be related to their low home values.

# %%
(Boston['rm'] > 7).sum()
# Out:
# np.int64(64)

# %%
(Boston['rm'] > 8).sum()
# Out:
# np.int64(13)

# %%
Boston[Boston['rm'] > 8]
# Out:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 97           98  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 224         225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
# 226         227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8
# 232         233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8
# 233         234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8
# 253         254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7
# 257         258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5
# 262         263  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5
# ...

# %% [markdown]
# There are 64 suburbs that average more than 7 rooms per dwelling and 13 suburbs that average more than 8 rooms. The suburbs with more than 8 rooms generally have high median home values and relatively low lstat values. Many of these suburbs appear to be wealthier areas with larger homes.
